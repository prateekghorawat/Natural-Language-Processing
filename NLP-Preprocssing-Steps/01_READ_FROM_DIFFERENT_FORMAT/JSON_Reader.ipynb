# %%
import json

# %%
with open("/content/drive/MyDrive/Colab Notebooks/NLP_Specialization/Data/sample.json" , "r") as f :
  read_sample = json.load(f)

print(f"Read Part from JSON is {read_sample}")
# Out:
# Read Part from JSON is {'Mathew': ['mathematics', 'chemistry'], 'Perry': ['biology', 'arts']}
