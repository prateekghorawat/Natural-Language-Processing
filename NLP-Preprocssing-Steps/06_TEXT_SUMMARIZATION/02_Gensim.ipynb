# %%
# !pip3 install gensim==3.6.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 44.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for gensim: filename=gensim-3.6.0-cp310-cp310-linux_x86_64.whl size=23778007 sha256=2e84cc62974b0cd347e93bd22d82d545c518b6b3ceadf3fa98c021edeed6d053
#   Stored in directory: /root/.cache/pip/wheels/00/e8/47/96f55c3144a5ea3537f549f7a97607011f5004b9f13fa8dcc5
# Successfully built gensim
# ...
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.2
#     Uninstalling gensim-4.3.2:
#       Successfully uninstalled gensim-4.3.2
# ...

# %%
import gensim
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-e70e92d32c6e> in <cell line: 1>()
# ----> 1 import gensim
#
# /usr/local/lib/python3.10/dist-packages/gensim/__init__.py in <module>
#       3 """
#       4
# ----> 5 from gensim import parsing, corpora, matutils, interfaces, models, similarities, summarization, utils  # noqa:F401
#       6 import logging
#       7
#
# /usr/local/lib/python3.10/dist-packages/gensim/corpora/__init__.py in <module>
#      10 from .svmlightcorpus import SvmLightCorpus  # noqa:F401
#      11 from .lowcorpus import LowCorpus  # noqa:F401
# ---> 12 from .dictionary import Dictionary  # noqa:F401
#      13 from .hashdictionary import HashDictionary  # noqa:F401
#      14 from .wikicorpus import WikiCorpus  # noqa:F401
#
# /usr/local/lib/python3.10/dist-packages/gensim/corpora/dictionary.py in <module>
# ...

# %%
from gensim.summarization import summarize
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-97f4c75239a4> in <cell line: 1>()
# ----> 1 from gensim.summarization import summarize
#
# /usr/local/lib/python3.10/dist-packages/gensim/__init__.py in <module>
#       3 """
#       4
# ----> 5 from gensim import parsing, corpora, matutils, interfaces, models, similarities, summarization, utils  # noqa:F401
#       6 import logging
#       7
#
# /usr/local/lib/python3.10/dist-packages/gensim/corpora/__init__.py in <module>
#      10 from .svmlightcorpus import SvmLightCorpus  # noqa:F401
#      11 from .lowcorpus import LowCorpus  # noqa:F401
# ---> 12 from .dictionary import Dictionary  # noqa:F401
#      13 from .hashdictionary import HashDictionary  # noqa:F401
#      14 from .wikicorpus import WikiCorpus  # noqa:F401
#
# /usr/local/lib/python3.10/dist-packages/gensim/corpora/dictionary.py in <module>
# ...

# %%
text = ""

gensim_summary = summarize(text, ratio=0.055)

print(gensim_summary)

# %%
print(gensim.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6f576414b71f> in <cell line: 1>()
# ----> 1 print(gensim.__version__)
#
# NameError: name 'gensim' is not defined
