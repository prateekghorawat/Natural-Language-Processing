# %%
import sklearn
from sklearn.metrics.pairwise import cosine_similarity

## Cosine_Similarity  = 1 - Cosine Distance

# %%
## Convert sentences into numbers here: (Embedding , one hot encodeing and so on )

# %%
## For example we are using direct encoded numbers
print(cosine_similarity([[1 , 2, 3 , 4 , 5]] , [[2, 3 ,4 , 5 , 6 ]]))
# Out:
# [[0.99493668]]
