# %%
import sklearn
from sklearn.metrics.pairwise import euclidean_distances

# %%
## Convert sentences into numbers here: (Embedding , one hot encodeing and so on )

# %%
## For example we are using direct encoded numbers
print(euclidean_distances([[1 , 2, 3 , 4 , 5]] , [[2, 3 ,4 , 5 , 6 ]]))
# Out:
# [[2.23606798]]

# %%
## Shape is very important, it is looking for 2d array...
