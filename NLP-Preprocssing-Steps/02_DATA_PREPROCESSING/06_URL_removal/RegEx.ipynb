# %%
import re

# %%
text = """
Check it out on https://google.com or www.google.com for more
information.
Reach out to abc@xyz.com for inquiries.
"""

# %%
url_clean = re.sub(r"https?://\S+|www\.\S+" , "" , text)
print(url_clean)
# Out:
# Check it out on  or  for more
# information.
# Reach out to abc@xyz.com for inquiries.
