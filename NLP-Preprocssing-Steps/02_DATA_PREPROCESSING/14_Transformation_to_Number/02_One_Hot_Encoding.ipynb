# %%
from sklearn.preprocessing import OneHotEncoder

# %%
x = [["Pop"], ["Rock"], ["Rock"]]
oenc = OneHotEncoder()
x_enc = oenc.fit_transform(x)

# %%
for i in range(len(x)) :
  print(f"{x[i]} : {x_enc[i]}")
# Out:
# ['Pop'] :   (0, 0)	1.0
# ['Rock'] :   (0, 1)	1.0
# ['Rock'] :   (0, 1)	1.0
