# %%
# !pip install nltk

# %%
import nltk
from nltk import sent_tokenize
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sentence = "Hi! , I am starting NLP and trying to learn more effectively. Where can I learn better?? Can you help me understand."
segmented_sentence = sent_tokenize(sentence)
print(segmented_sentence)
# Out:
# ['Hi!', ', I am starting NLP and trying to learn more effectively.', 'Where can I learn better??', 'Can you help me understand.']
