# %%
# !pip install spacy

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(u"Hi!!!! I have started, learning NLP. I am just hoping I like it. Would, you like to share your experience???")

for sentence in doc.sents:
  print(sentence)
# Out:
# Hi!!!!
# I have started, learning NLP.
# I am just hoping I like it.
# Would, you like to share your experience???
