# %%
import re

# %%
text = "Hi!! there I am , new here, can you please help me out.."

# %%
punc_removed = re.sub(r"[^\w\s\n]" , "" , text)

# %%
punc_removed
# Out:
# 'Hi there I am  new here can you please help me out'
