# %%
# !pip install textblob

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from textblob import TextBlob

# %%
text = "Hi!! there I am here to learn NLP.. Can you please help me out?"
print(text)
# Out:
# Hi!! there I am here to learn NLP.. Can you please help me out?

# %%
tokens = TextBlob(text).words
print(tokens)
# Out:
# ['Hi', 'there', 'I', 'am', 'here', 'to', 'learn', 'NLP', 'Can', 'you', 'please', 'help', 'me', 'out']
