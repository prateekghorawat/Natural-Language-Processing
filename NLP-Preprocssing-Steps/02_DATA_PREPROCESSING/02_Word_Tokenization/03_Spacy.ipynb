# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = "Hi! there can we move to U.K., I bet it will be a wonderful experince"

# %%
tokens = nlp(text)

# %%
for token in tokens :
  print(token)
# Out:
# Hi
# !
# there
# can
# we
# move
# to
# U.K.
# ,
# I
# bet
# it
# will
# be
# a
# wonderful
# experince
