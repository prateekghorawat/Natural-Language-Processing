# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk import word_tokenize

# %%
text = "Hi! I would like to learning NLP. Can you let me know where to learn from U.K."

# %%
tokens = word_tokenize(text)
tokens
# Out:
# ['Hi',
#  '!',
#  'I',
#  'would',
#  'like',
#  'to',
#  'learning',
#  'NLP',
#  '.',
#  'Can',
#  'you',
#  'let',
#  'me',
#  'know',
#  'where',
#  'to',
#  'learn',
#  'from',
#  'U.K',
#  '.']

# %%
len(tokens)
# Out:
# 20
