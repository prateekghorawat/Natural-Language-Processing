# %%
# !pip install spacy

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp ( u'the bats saw the cats ')

# %%
lemmetized = []
for token in doc :
  lemmetized.append(token.lemma_)
print(lemmetized)
# Out:
# ['the', 'bat', 'see', 'the', 'cat']
