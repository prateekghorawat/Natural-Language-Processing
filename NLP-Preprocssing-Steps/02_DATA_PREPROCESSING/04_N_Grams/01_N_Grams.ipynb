# %%
from textblob import TextBlob
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
text = "Hi there we are starting Natural Language Processing"

# %%
TextBlob(text).ngrams(5)
# Out:
# [WordList(['Hi', 'there', 'we', 'are', 'starting']),
#  WordList(['there', 'we', 'are', 'starting', 'Natural']),
#  WordList(['we', 'are', 'starting', 'Natural', 'Language']),
#  WordList(['are', 'starting', 'Natural', 'Language', 'Processing'])]
